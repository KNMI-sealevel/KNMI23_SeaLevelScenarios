# %% [markdown]
# # Model selection based on multiple criteria

# %% [markdown]
# Produce a tables and lists of CMIP6 models that fulfill observational constraints: Ocean dynamic sea level (ODSL), global theral expansion (GTE),  equilibrium climate sensitivity (ECS) and Antarctic dynamics.

# %%
import numpy as np
import pandas as pd
import xarray as xr

import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('retina')

# %% [markdown]
# ## Read model selection for ODSL

# %%
odsl_df = pd.read_csv("./outputs/CMIP6_ODSL_selection.csv")
odsl_df.set_index("model", inplace=True)

# %%
list(odsl_df.loc[odsl_df.ODSL=="Good"].index)
# Out:
# ['ACCESS-ESM1-5',
#  'CESM2-WACCM',
#  'CNRM-CM6-1',
#  'CNRM-ESM2-1',
#  'EC-Earth3',
#  'GISS-E2-1-G',
#  'INM-CM4-8',
#  'MIROC-ES2L',
#  'MPI-ESM1-2-LR',
#  'NESM3',
#  'NorESM2-LM',
#  'NorESM2-MM',
#  'UKESM1-0-LL']

# %% [markdown]
# ## GTE: Comparison with the models from Lyu et al. 2021 selected for thermal expansion

# %% [markdown]
# Use data from the supplementary material to make a dataframe.

# %%
data_ECS = np.array([
['A', 'ACCESS-CM2', 4.66],
['B', 'ACCESS-ESM1-5', 3.88],
['C', 'BCC-CSM2-MR', 3.02],
['D', 'CAMS-CSM1-0', 2.29],
['E', 'CanESM5', 5.64],
['F', 'CESM2', 5.15],
['G', 'CESM2-WACCM', 4.68],
['H', 'CIESM', 5.67],
['I', 'CMCC-CM2-SR5', 3.55],
['J', 'CNRM-CM6-1', 4.90],
['K', 'CNRM-ESM2-1', 4.79],
['L', 'EC-Earth3', 4.26],
['M', 'EC-Earth3-Veg', 4.33],
['N', 'FGOALS-f3-L', 2.98],
['O', 'FGOALS-g3', 2.87],
['P', 'FIO-ESM-2-0', np.nan],
['Q', 'GFDL-CM4', 3.89],
['R', 'GISS-E2-1-G', 2.71],
['S', 'HadGEM3-GC31-LL', 5.55],
['T', 'IPSL-CM6A-LR', 4.7],
['U', 'MIROC6', 2.6],
['V', 'MIROC-ES2L', 2.66],
['W', 'MPI-ESM1-2-HR', 2.98],
['X', 'MPI-ESM1-2-LR', 3.03],
['Y', 'MRI-ESM2-0', 3.13],
['Z', 'NorESM2-LM', 2.56],
['a', 'NorESM2-MM', 2.49],
['b', 'UKESM1-0-LL', 5.36],
])

ECS_df = pd.DataFrame(columns=['letter', 'model', 'ECS'] , data=data_ECS)
ECS_df["ECS"] = ECS_df["ECS"].apply(pd.to_numeric, errors='coerce')
ECS_df.set_index('letter', inplace=True)

# Data from Figure 3b of Lyu et al. 2021

letters_gts_too_low = ['K']
letters_gts_sel = ['X', 'U', 'I', 'J', 'a', 'D', 'L', 'Z', 'C', 'N', 'M', 'Y']
letters_gts_too_high = ['Q', 'T', 'W', 'O', 'V', 'B', 'P', 'R', 'F', 'A', 'b', 'G', 'E', 'S', 'H']

# %%
print(f"Total number of CMIP6 models in Lyu et al. 2021: {len(ECS_df)}")
print(f"{len(letters_gts_sel)} models are selected: ")
print(sorted(list(ECS_df.loc[letters_gts_sel].model)))

print(f"{len(letters_gts_too_high)} models have too high rates: ")
print(sorted(list(ECS_df.loc[letters_gts_too_high].model)))

print(f"{len(letters_gts_too_low)} models have too low rates: ")
print(sorted(list(ECS_df.loc[letters_gts_too_low].model)))
# Out:
# Total number of CMIP6 models in Lyu et al. 2021: 28
# 12 models are selected:
# ['BCC-CSM2-MR', 'CAMS-CSM1-0', 'CMCC-CM2-SR5', 'CNRM-CM6-1', 'EC-Earth3', 'EC-Earth3-Veg', 'FGOALS-f3-L', 'MIROC6', 'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NorESM2-LM', 'NorESM2-MM']
# 15 models have too high rates:
# ['ACCESS-CM2', 'ACCESS-ESM1-5', 'CESM2', 'CESM2-WACCM', 'CIESM', 'CanESM5', 'FGOALS-g3', 'FIO-ESM-2-0', 'GFDL-CM4', 'GISS-E2-1-G', 'HadGEM3-GC31-LL', 'IPSL-CM6A-LR', 'MIROC-ES2L', 'MPI-ESM1-2-HR', 'UKESM1-0-LL']
# 1 models have too low rates:
# ['CNRM-ESM2-1']

# %% [markdown]
# Store all the data into a dataframe

# %%
gte_df = pd.DataFrame({"GTE": np.zeros(len(ECS_df))}, index=ECS_df.model)
gte_df.index.name = "model"

gte_df.loc[list(ECS_df.loc[letters_gts_sel].model)] = "Good"
gte_df.loc[list(ECS_df.loc[letters_gts_too_high].model)] = "TooHigh"
gte_df.loc[list(ECS_df.loc[letters_gts_too_low].model)] = "TooLow"

# %%
gte_df
# Out:
#                      GTE
# model
# ACCESS-CM2       TooHigh
# ACCESS-ESM1-5    TooHigh
# BCC-CSM2-MR         Good
# CAMS-CSM1-0         Good
# CanESM5          TooHigh
# CESM2            TooHigh
# CESM2-WACCM      TooHigh
# CIESM            TooHigh
# CMCC-CM2-SR5        Good
# CNRM-CM6-1          Good
# CNRM-ESM2-1       TooLow
# EC-Earth3           Good
# EC-Earth3-Veg       Good
# FGOALS-f3-L         Good
# FGOALS-g3        TooHigh
# FIO-ESM-2-0      TooHigh
# GFDL-CM4         TooHigh
# GISS-E2-1-G      TooHigh
# HadGEM3-GC31-LL  TooHigh
# IPSL-CM6A-LR     TooHigh
# MIROC6              Good
# MIROC-ES2L       TooHigh
# MPI-ESM1-2-HR    TooHigh
# MPI-ESM1-2-LR       Good
# MRI-ESM2-0          Good
# NorESM2-LM          Good
# NorESM2-MM          Good
# UKESM1-0-LL      TooHigh

# %% [markdown]
# ## ECS

# %% [markdown]
# AR6 decided on a very likely range of ECS of 2 to 5ºC and a likely range of 2.5 to 4ºC. Here we use the very likely range for selection.

# %%
ecs_or_df = ECS_df.set_index("model")

ecs_df = ecs_or_df.copy()

ecs_df.loc[(ecs_or_df.ECS < 5) & (ecs_or_df.ECS > 2)] = "Good"
ecs_df.loc[ecs_or_df.ECS > 5 ] = "TooHigh"
ecs_df.loc[ecs_or_df.ECS < 2] = "TooLow"

ecs_df
# Out:
#                      ECS
# model
# ACCESS-CM2          Good
# ACCESS-ESM1-5       Good
# BCC-CSM2-MR         Good
# CAMS-CSM1-0         Good
# CanESM5          TooHigh
# CESM2            TooHigh
# CESM2-WACCM         Good
# CIESM            TooHigh
# CMCC-CM2-SR5        Good
# CNRM-CM6-1          Good
# CNRM-ESM2-1         Good
# EC-Earth3           Good
# EC-Earth3-Veg       Good
# FGOALS-f3-L         Good
# FGOALS-g3           Good
# FIO-ESM-2-0          NaN
# GFDL-CM4            Good
# GISS-E2-1-G         Good
# HadGEM3-GC31-LL  TooHigh
# IPSL-CM6A-LR        Good
# MIROC6              Good
# MIROC-ES2L          Good
# MPI-ESM1-2-HR       Good
# MPI-ESM1-2-LR       Good
# MRI-ESM2-0          Good
# NorESM2-LM          Good
# NorESM2-MM          Good
# UKESM1-0-LL      TooHigh

# %% [markdown]
# ## Antarctic dynamics

# %%
path_aa = "/Users/dewilebars/Projects/Project_ProbSLR/Data_Proj/DataAntarctica_vdl/"

# %%
ls {path_aa}
# Out:
# README.txt
# slr_AMUNcalibrated_quadM_thetao_merged_biasadj_shelfbasedepth_historical+ssp126_1850-2100.nc
# slr_AMUNcalibrated_quadM_thetao_merged_biasadj_shelfbasedepth_historical+ssp245_1850-2100.nc
# slr_AMUNcalibrated_quadM_thetao_merged_biasadj_shelfbasedepth_historical+ssp585_1850-2100.nc
# table_AIS_dynamics_estimates.docx
# top10pct_models_AMUNcalibrated_quadM_shelfbasedepth.txt
# top20pct_models_AMUNcalibrated_quadM_shelfbasedepth.txt

# %%
aa_t10 = pd.read_csv(f"{path_aa}/top10pct_models_AMUNcalibrated_quadM_shelfbasedepth.txt", 
                  names = ["ESM", "ISM"],
                  delim_whitespace=True)

aa_t20 = pd.read_csv(f"{path_aa}/top20pct_models_AMUNcalibrated_quadM_shelfbasedepth.txt", 
                  names = ["ESM", "ISM"],
                  delim_whitespace=True)

# %%
aa_t20
# Out:
#               ESM           ISM
# 0      MRI-ESM2-0      ISSM_UCI
# 1       INM-CM4-8      MALI_LAN
# 2      MRI-ESM2-0      ISSM_JPL
# 3      MRI-ESM2-0      CISM_NCA
# 4         CanESM5      ISSM_UCI
# 5      MRI-ESM2-0      MALI_LAN
# 6       EC-Earth3      SICO_UHO
# 7       INM-CM5-0      ISSM_JPL
# 8      MRI-ESM2-0      IMAU_VUB
# 9       INM-CM4-8      CISM_NCA
# 10     MRI-ESM2-0      AISM_VUB
# 11        CanESM5      AISM_VUB
# 12      INM-CM4-8      AISM_VUB
# 13      INM-CM4-8      SICO_UHO
# 14        CanESM5        UA_UNN
# 15        CanESM5      ISSM_JPL
# 16      EC-Earth3  BISI_LBL_1KM
# 17     MRI-ESM2-0        UA_UNN
# 18      INM-CM4-8        UA_UNN
# 19     MRI-ESM2-0      SICO_UHO
# 20        CanESM5      SICO_UHO
# 21     MRI-ESM2-0  BISI_LBL_1KM
# 22     MRI-ESM2-0      PISM_AWI
# 23      INM-CM4-8      ISSM_JPL
# 24        CanESM5      PISM_AWI
# 25      EC-Earth3      ISSM_JPL
# 26      INM-CM4-8      ISSM_UCI
# 27      INM-CM4-8      PISM_VUW
# 28      INM-CM5-0      MALI_LAN
# 29  MPI-ESM1-2-LR      MALI_LAN
# 30      EC-Earth3      ISSM_UCI
# 31     ACCESS-CM2      AISM_VUB
# 32    CAMS-CSM1-0      AISM_VUB
# 33     CAS-ESM2-0      AISM_VUB
# 34      INM-CM4-8      PISM_AWI
# 35    CAMS-CSM1-0        UA_UNN
# 36        CanESM5      MALI_LAN
# 37    CAMS-CSM1-0      ISSM_UCI
# 38  MPI-ESM1-2-LR      ISSM_JPL
# 39      INM-CM5-0      ISSM_UCI
# 40  MPI-ESM1-2-LR      AISM_VUB
# 41      EC-Earth3      MALI_LAN
# 42      EC-Earth3      IMAU_VUB
# 43  MPI-ESM1-2-LR        UA_UNN

# %%
top10_ESM = list(set(aa_t10.ESM))
aa10_df = pd.DataFrame({"AA top 10pc": ["Good"]*len(set(aa_t10.ESM))}, index=top10_ESM)

top20_ESM = list(set(aa_t20.ESM))
aa20_df = pd.DataFrame({"AA top 20pc": ["Good"]*len(set(aa_t20.ESM))}, index=top20_ESM)

# %%
aa20_df
# Out:
#               AA top 20pc
# CanESM5              Good
# EC-Earth3            Good
# MRI-ESM2-0           Good
# INM-CM4-8            Good
# CAMS-CSM1-0          Good
# MPI-ESM1-2-LR        Good
# INM-CM5-0            Good
# ACCESS-CM2           Good
# CAS-ESM2-0           Good

# %% [markdown]
# ## Prepare final table

# %%
all_df = pd.concat([ecs_df, gte_df, odsl_df, aa10_df], axis=1, join="outer")

#aa20_df
# Add a final line on number of models available

all_df
# Out:
#                      ECS      GTE     ODSL AA top 10pc
# ACCESS-CM2          Good  TooHigh  TooHigh         NaN
# ACCESS-ESM1-5       Good  TooHigh     Good         NaN
# BCC-CSM2-MR         Good     Good   TooLow         NaN
# CAMS-CSM1-0         Good     Good  TooHigh         NaN
# CanESM5          TooHigh  TooHigh  TooHigh        Good
# CESM2            TooHigh  TooHigh      NaN         NaN
# CESM2-WACCM         Good  TooHigh     Good         NaN
# CIESM            TooHigh  TooHigh      NaN         NaN
# CMCC-CM2-SR5        Good     Good  TooHigh         NaN
# CNRM-CM6-1          Good     Good     Good         NaN
# CNRM-ESM2-1         Good   TooLow     Good         NaN
# EC-Earth3           Good     Good     Good        Good
# EC-Earth3-Veg       Good     Good  TooHigh         NaN
# FGOALS-f3-L         Good     Good      NaN         NaN
# FGOALS-g3           Good  TooHigh      NaN         NaN
# FIO-ESM-2-0          NaN  TooHigh      NaN         NaN
# GFDL-CM4            Good  TooHigh      NaN         NaN
# GISS-E2-1-G         Good  TooHigh     Good         NaN
# HadGEM3-GC31-LL  TooHigh  TooHigh  TooHigh         NaN
# IPSL-CM6A-LR        Good  TooHigh  TooHigh         NaN
# MIROC6              Good     Good  TooHigh         NaN
# MIROC-ES2L          Good  TooHigh     Good         NaN
# MPI-ESM1-2-HR       Good  TooHigh  TooHigh         NaN
# MPI-ESM1-2-LR       Good     Good     Good         NaN
# MRI-ESM2-0          Good     Good  TooHigh        Good
# NorESM2-LM          Good     Good     Good         NaN
# NorESM2-MM          Good     Good     Good         NaN
# UKESM1-0-LL      TooHigh  TooHigh     Good         NaN
# CanESM5-CanOE        NaN      NaN  TooHigh         NaN
# INM-CM4-8            NaN      NaN     Good        Good
# INM-CM5-0            NaN      NaN  TooHigh        Good
# NESM3                NaN      NaN     Good         NaN

# %%
def color(val):
    if val == "Good":
        color = "green"
    elif val == "TooHigh":
        color = "red"
    elif val == "TooLow":
        color = "Blue"
    elif np.isnan(val):
        color = "grey"
    return 'background-color: %s' % color

all_df.style.applymap(color)
# Out:
# <style type="text/css">
# #T_17058_row0_col0, #T_17058_row1_col0, #T_17058_row1_col2, #T_17058_row2_col0, #T_17058_row2_col1, #T_17058_row3_col0, #T_17058_row3_col1, #T_17058_row4_col3, #T_17058_row6_col0, #T_17058_row6_col2, #T_17058_row8_col0, #T_17058_row8_col1, #T_17058_row9_col0, #T_17058_row9_col1, #T_17058_row9_col2, #T_17058_row10_col0, #T_17058_row10_col2, #T_17058_row11_col0, #T_17058_row11_col1, #T_17058_row11_col2, #T_17058_row11_col3, #T_17058_row12_col0, #T_17058_row12_col1, #T_17058_row13_col0, #T_17058_row13_col1, #T_17058_row14_col0, #T_17058_row16_col0, #T_17058_row17_col0, #T_17058_row17_col2, #T_17058_row19_col0, #T_17058_row20_col0, #T_17058_row20_col1, #T_17058_row21_col0, #T_17058_row21_col2, #T_17058_row22_col0, #T_17058_row23_col0, #T_17058_row23_col1, #T_17058_row23_col2, #T_17058_row24_col0, #T_17058_row24_col1, #T_17058_row24_col3, #T_17058_row25_col0, #T_17058_row25_col1, #T_17058_row25_col2, #T_17058_row26_col0, #T_17058_row26_col1, #T_17058_row26_col2, #T_17058_row27_col2, #T_17058_row29_col2, #T_17058_row29_col3, #T_17058_row30_col3, #T_17058_row31_col2 {
#   background-color: green;
# }
# #T_17058_row0_col1, #T_17058_row0_col2, #T_17058_row1_col1, #T_17058_row3_col2, #T_17058_row4_col0, #T_17058_row4_col1, #T_17058_row4_col2, #T_17058_row5_col0, #T_17058_row5_col1, #T_17058_row6_col1, #T_17058_row7_col0, #T_17058_row7_col1, #T_17058_row8_col2, #T_17058_row12_col2, #T_17058_row14_col1, #T_17058_row15_col1, #T_17058_row16_col1, #T_17058_row17_col1, #T_17058_row18_col0, #T_17058_row18_col1, #T_17058_row18_col2, #T_17058_row19_col1, #T_17058_row19_col2, #T_17058_row20_col2, #T_17058_row21_col1, #T_17058_row22_col1, #T_17058_row22_col2, #T_17058_row24_col2, #T_17058_row27_col0, #T_17058_row27_col1, #T_17058_row28_col2, #T_17058_row30_col2 {
#   background-color: red;
# }
# #T_17058_row0_col3, #T_17058_row1_col3, #T_17058_row2_col3, #T_17058_row3_col3, #T_17058_row5_col2, #T_17058_row5_col3, #T_17058_row6_col3, #T_17058_row7_col2, #T_17058_row7_col3, #T_17058_row8_col3, #T_17058_row9_col3, #T_17058_row10_col3, #T_17058_row12_col3, #T_17058_row13_col2, #T_17058_row13_col3, #T_17058_row14_col2, #T_17058_row14_col3, #T_17058_row15_col0, #T_17058_row15_col2, #T_17058_row15_col3, #T_17058_row16_col2, #T_17058_row16_col3, #T_17058_row17_col3, #T_17058_row18_col3, #T_17058_row19_col3, #T_17058_row20_col3, #T_17058_row21_col3, #T_17058_row22_col3, #T_17058_row23_col3, #T_17058_row25_col3, #T_17058_row26_col3, #T_17058_row27_col3, #T_17058_row28_col0, #T_17058_row28_col1, #T_17058_row28_col3, #T_17058_row29_col0, #T_17058_row29_col1, #T_17058_row30_col0, #T_17058_row30_col1, #T_17058_row31_col0, #T_17058_row31_col1, #T_17058_row31_col3 {
#   background-color: grey;
# }
# #T_17058_row2_col2, #T_17058_row10_col1 {
#   background-color: Blue;
# }
# </style>
# <table id="T_17058">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17058_level0_col0" class="col_heading level0 col0" >ECS</th>
#       <th id="T_17058_level0_col1" class="col_heading level0 col1" >GTE</th>
#       <th id="T_17058_level0_col2" class="col_heading level0 col2" >ODSL</th>
#       <th id="T_17058_level0_col3" class="col_heading level0 col3" >AA top 10pc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17058_level0_row0" class="row_heading level0 row0" >ACCESS-CM2</th>
#       <td id="T_17058_row0_col0" class="data row0 col0" >Good</td>
#       <td id="T_17058_row0_col1" class="data row0 col1" >TooHigh</td>
#       <td id="T_17058_row0_col2" class="data row0 col2" >TooHigh</td>
#       <td id="T_17058_row0_col3" class="data row0 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row1" class="row_heading level0 row1" >ACCESS-ESM1-5</th>
#       <td id="T_17058_row1_col0" class="data row1 col0" >Good</td>
#       <td id="T_17058_row1_col1" class="data row1 col1" >TooHigh</td>
#       <td id="T_17058_row1_col2" class="data row1 col2" >Good</td>
#       <td id="T_17058_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row2" class="row_heading level0 row2" >BCC-CSM2-MR</th>
#       <td id="T_17058_row2_col0" class="data row2 col0" >Good</td>
#       <td id="T_17058_row2_col1" class="data row2 col1" >Good</td>
#       <td id="T_17058_row2_col2" class="data row2 col2" >TooLow</td>
#       <td id="T_17058_row2_col3" class="data row2 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row3" class="row_heading level0 row3" >CAMS-CSM1-0</th>
#       <td id="T_17058_row3_col0" class="data row3 col0" >Good</td>
#       <td id="T_17058_row3_col1" class="data row3 col1" >Good</td>
#       <td id="T_17058_row3_col2" class="data row3 col2" >TooHigh</td>
#       <td id="T_17058_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row4" class="row_heading level0 row4" >CanESM5</th>
#       <td id="T_17058_row4_col0" class="data row4 col0" >TooHigh</td>
#       <td id="T_17058_row4_col1" class="data row4 col1" >TooHigh</td>
#       <td id="T_17058_row4_col2" class="data row4 col2" >TooHigh</td>
#       <td id="T_17058_row4_col3" class="data row4 col3" >Good</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row5" class="row_heading level0 row5" >CESM2</th>
#       <td id="T_17058_row5_col0" class="data row5 col0" >TooHigh</td>
#       <td id="T_17058_row5_col1" class="data row5 col1" >TooHigh</td>
#       <td id="T_17058_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_17058_row5_col3" class="data row5 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row6" class="row_heading level0 row6" >CESM2-WACCM</th>
#       <td id="T_17058_row6_col0" class="data row6 col0" >Good</td>
#       <td id="T_17058_row6_col1" class="data row6 col1" >TooHigh</td>
#       <td id="T_17058_row6_col2" class="data row6 col2" >Good</td>
#       <td id="T_17058_row6_col3" class="data row6 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row7" class="row_heading level0 row7" >CIESM</th>
#       <td id="T_17058_row7_col0" class="data row7 col0" >TooHigh</td>
#       <td id="T_17058_row7_col1" class="data row7 col1" >TooHigh</td>
#       <td id="T_17058_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_17058_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row8" class="row_heading level0 row8" >CMCC-CM2-SR5</th>
#       <td id="T_17058_row8_col0" class="data row8 col0" >Good</td>
#       <td id="T_17058_row8_col1" class="data row8 col1" >Good</td>
#       <td id="T_17058_row8_col2" class="data row8 col2" >TooHigh</td>
#       <td id="T_17058_row8_col3" class="data row8 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row9" class="row_heading level0 row9" >CNRM-CM6-1</th>
#       <td id="T_17058_row9_col0" class="data row9 col0" >Good</td>
#       <td id="T_17058_row9_col1" class="data row9 col1" >Good</td>
#       <td id="T_17058_row9_col2" class="data row9 col2" >Good</td>
#       <td id="T_17058_row9_col3" class="data row9 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row10" class="row_heading level0 row10" >CNRM-ESM2-1</th>
#       <td id="T_17058_row10_col0" class="data row10 col0" >Good</td>
#       <td id="T_17058_row10_col1" class="data row10 col1" >TooLow</td>
#       <td id="T_17058_row10_col2" class="data row10 col2" >Good</td>
#       <td id="T_17058_row10_col3" class="data row10 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row11" class="row_heading level0 row11" >EC-Earth3</th>
#       <td id="T_17058_row11_col0" class="data row11 col0" >Good</td>
#       <td id="T_17058_row11_col1" class="data row11 col1" >Good</td>
#       <td id="T_17058_row11_col2" class="data row11 col2" >Good</td>
#       <td id="T_17058_row11_col3" class="data row11 col3" >Good</td>
#     </tr>
#     <tr>
#       <th id="T_17058_level0_row12" class="row_heading level0 row12" >EC-Earth3-Veg</th>
#       <td id="T_17058_row12_col0" class="data row12 col0" >Good</td>
#       <td id="T_17058_row12_col1" class="data row12 col1" >Good</td>
#       <td id="T_17058_row12_col2" cla

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Since there are not enough models fulfilling all criteria the method will focus on different selection. One the one hand ODSL and GTE are selected and on the other hand Antarctica.
